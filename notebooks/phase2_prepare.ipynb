# %% [markdown]
# # Phase 2 Prepare
#
# This step prepares the large `Appliances.json.gz` dataset, applies reproducible preprocessing, saves the development sample, and writes the shared comparison subset used by both lexicon and machine-learning models.

# %% [markdown]
# Run:
#
# ```bash
# uv run python -m src.prepare_phase2
# ```
