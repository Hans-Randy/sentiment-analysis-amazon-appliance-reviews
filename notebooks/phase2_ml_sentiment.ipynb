# %% [markdown]
# # Phase 2: Baseline ML Sentiment Model
#
# This notebook keeps the ML workflow readable while reusing the shared preprocessing and evaluation code from `src/`. Phase 2 explicitly uses the larger `data/raw/Appliances.json.gz` dataset.
#
# Recommended workflow:
# 1. Run `src.prepare_phase2` to prepare the large dataset and save exploration outputs
# 2. Run the model-specific tuning scripts only when retuning is needed (`tune_logistic_regression`, `tune_multinomial_nb`, `tune_svm`)
# 3. Update fixed defaults in `src.train_ml.py`
# 4. Run `src.train_ml` for the normal training/evaluation pipeline

# %%
from src.train_ml import run_ml_pipeline

# %%
outputs = run_ml_pipeline()
outputs['cv_summary'], outputs['ml_summary'], outputs['comparison']

# %% [markdown]
# Useful commands:
# - `uv run python -m src.prepare_phase2`
# - `uv run python -m src.tune_logistic_regression`
# - `uv run python -m src.tune_multinomial_nb`
# - `uv run python -m src.tune_svm`
# - `uv run python -m src.train_ml`
#
# Key saved artifacts:
# - `outputs/predictions/phase2_ml_all_test_predictions.csv`
# - `outputs/predictions/phase2_lexicon_comparison_subset.csv`
# - `outputs/tables/phase2_dataset_overview.csv`
# - `outputs/tables/phase2_cross_validation_summary.csv`
# - `outputs/tables/phase2_ml_model_summary.csv`
# - `outputs/tables/phase2_model_comparison.csv`
# - `outputs/tables/tuning_logistic_regression.csv`
# - `outputs/tables/tuning_multinomial_nb.csv`
# - `outputs/tables/tuning_svm.csv`
