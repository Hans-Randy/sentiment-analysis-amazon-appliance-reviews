# %% [markdown]
# # Phase 2: Baseline ML Sentiment Model
#
# This notebook keeps the ML workflow readable while reusing the shared preprocessing and evaluation code from `src/`. Phase 2 explicitly uses the larger `data/raw/Appliances.json.gz` dataset.
#
# Current baselines:
# - Features: TF-IDF on combined `summary + reviewText`
# - ML models: Logistic regression, Linear SVC, Multinomial Naive Bayes
# - Validation: 3-fold cross-validation on the training split of a reproducible development sample
# - Tuning: lightweight grid search for logistic regression and Linear SVC
# - Comparison set: VADER, TextBlob, SentiWordNet on a shared stratified comparison subset from the large-dataset test split

# %%
from src.train_ml import run_ml_pipeline

# %%
outputs = run_ml_pipeline()
outputs['cv_summary'], outputs['tuning_summary'], outputs['ml_summary'], outputs['comparison']

# %% [markdown]
# Key saved artifacts:
# - `outputs/predictions/phase2_ml_all_test_predictions.csv`
# - `outputs/predictions/phase2_lexicon_comparison_subset.csv`
# - `outputs/predictions/phase2_logisticregression_test_predictions.csv`
# - `outputs/predictions/phase2_linearsvc_test_predictions.csv`
# - `outputs/predictions/phase2_multinomialnb_test_predictions.csv`
# - `outputs/predictions/phase2_test_lexicon_predictions.csv`
# - `outputs/tables/phase2_dataset_overview.csv`
# - `outputs/tables/phase2_cross_validation_summary.csv`
# - `outputs/tables/phase2_hyperparameter_search.csv`
# - `outputs/tables/phase2_ml_model_summary.csv`
# - `outputs/tables/phase2_model_comparison.csv`
# - `outputs/tables/phase2_logisticregression_error_analysis.csv`
# - `outputs/tables/phase2_linearsvc_error_analysis.csv`
# - `outputs/tables/phase2_multinomialnb_error_analysis.csv`
# - `outputs/tables/phase2_logisticregression_class_distribution.csv`
# - `outputs/figures/phase2_raw_rating_distribution.png`
# - `outputs/figures/phase2_prepared_rating_distribution.png`
# - `outputs/figures/phase2_reviewer_bias_analysis.png`
# - `outputs/figures/phase2_reviewer_rating_map.png`
# - `outputs/figures/phase2_reviewer_word_count.png`
# - `outputs/metrics/phase2_logisticregression_metrics.json`
# - `outputs/metrics/phase2_linearsvc_metrics.json`
# - `outputs/metrics/phase2_multinomialnb_metrics.json`
# - `outputs/metrics/phase2_split_summary.json`
