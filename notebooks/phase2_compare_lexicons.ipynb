# %% [markdown]
# # Phase 2 Compare Lexicons
#
# This notebook runs VADER, TextBlob, and SentiWordNet on the shared saved comparison subset so they can be compared fairly against the machine-learning models.
#
# Run:
# ```bash
# uv run python -m src.compare_lexicons
# ```
