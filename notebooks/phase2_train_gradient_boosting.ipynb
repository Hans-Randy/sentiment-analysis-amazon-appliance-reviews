# %% [markdown]
# # Phase 2 Train Gradient Boosting
#
# This notebook isolates the experimental Gradient Boosting run so it can be evaluated separately from the default text baselines.
#
# Run:
# ```bash
# uv run python -m src.train_ml --models gradient_boosting --skip-lexicon
# ```
