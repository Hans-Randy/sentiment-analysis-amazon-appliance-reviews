# %% [markdown]
# # Phase 2 Workflow Index
#
# Phase 2 is split into focused notebooks that mirror the CLI workflow and keep the experiment reproducible and easy to rerun.

# %% [markdown]
# ## Notebook Order
#
# 1. `phase2_prepare.ipynb`
# 2. `phase2_train_default_models.ipynb`
# 3. `phase2_train_mlp.ipynb`
# 4. `phase2_train_gradient_boosting.ipynb`
# 5. `phase2_compare_lexicons.ipynb`
# 6. `phase2_compare_models.ipynb`
