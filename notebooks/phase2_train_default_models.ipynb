# %% [markdown]
# # Phase 2 Train Default Models
#
# This notebook covers Logistic Regression, SVM, and Multinomial Naive Bayes on the prepared Phase 2 dataset.
#
# Run:
# ```bash
# uv run python -m src.train_ml --models logistic_regression svm multinomial_nb --skip-lexicon
# ```
