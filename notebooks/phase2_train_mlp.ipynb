# %% [markdown]
# # Phase 2 Train MLP
#
# This notebook isolates the experimental MLP run so its cost does not affect the default baseline workflow.
#
# Run:
# ```bash
# uv run python -m src.train_ml --models mlp --skip-lexicon
# ```
