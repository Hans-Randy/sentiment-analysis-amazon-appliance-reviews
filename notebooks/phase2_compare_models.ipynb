# %% [markdown]
# # Phase 2 Compare Models
#
# This notebook aggregates the saved comparison metrics from all trained ML models and the lexicon baselines.
#
# Run:
# ```bash
# uv run python -m src.compare_models
# ```
